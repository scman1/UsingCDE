# %% [markdown]
# # Reading HTML Documents
#
# This section contains a modified example shown based on the [reading documents page](http://chemdataextractor.org/docs/reading) of the Chem Data Extractor (CDE) documentation. The HTML document  used in this example can be accessed at :
# [Silveri, F., Quesne, M. G., Roldan, A., De Leeuw, N. H., & Catlow, C. R. A. (2019). Hydrogen adsorption on transition metal carbides: a DFT study. Physical Chemistry Chemical Physics, 21(10), 5335-5343](https://pubs.rsc.org/ko/content/articlehtml/2019/cp/c8cp05975f).

# %%
# The line of code (LOC) below imports the document object from the CDE library 
from chemdataextractor import Document

# library for handling html requests (reading online pages)
import requests

# The HTML document used in this example is the online version of:
# Silveri, F., Quesne, M. G., Roldan, A., De Leeuw, N. H., & Catlow, C. R. A. (2019). 
# Hydrogen adsorption on transition metal carbides: a DFT study. Physical Chemistry 
# Chemical Physics, 21(10), 5335-5343.

# the path for the html file is used directly
article_url = "https://pubs.rsc.org/ko/content/articlehtml/2019/cp/c8cp05975f"

# set request header
req_head = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'}
# get the page content 
html_response = requests.get(article_url, headers = req_head)
#save the content as a temporary file in the local disk
f= open("temp.html","w+")
f.write(str(html_response.content))
f.close()

# open de temporary file and read in binary mode
f = open("temp.html", 'rb')

# create a document object from the file
doc = Document.from_file(f)

# %% [markdown]
# The document is made up of the paragraphs, each paragraph is an element (some are short because they include the title only).
#
# The elements of a document are part of a list. So list operations can be used to explore the list.

# %%
#To see the length of the elements list
len(doc.elements)
doc.elements
# Out:
# [Paragraph(id='wrapper', references=[], text=' Open Access Article'),
#  Paragraph(id='wrapper', references=[], text='\\nThis Open Access Article is licensed under a '),
#  Paragraph(id='wrapper', references=[], text='Creative Commons Attribution 3.0 Unported Licence'),
#  Paragraph(id='wrapper', references=[], text=' DOI:\\xc2\\xa010.1039/C8CP05975F\\n(Paper)\\nPhys. Chem. Chem. Phys., 2019, 21, 5335-5343'),
#  Title(id='sect187', references=['fn1'], text='Hydrogen adsorption on transition metal carbides: a DFT study'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n \\n Fabrizio \\n Silveri\\n \\n \\n *, \\n \\n \\n \\n Matthew G. \\n Quesne\\n \\n \\n , \\n \\n \\n \\n Alberto \\n Roldan\\n \\n \\n , \\n \\n \\n \\n Nora H. \\n de Leeuw\\n \\n \\n  and \\n \\n \\n \\n C. Richard A. \\n Catlow\\n \\n \\n \\n '),
#  Paragraph(id='wrapper', references=[], text='School of Chemistry, Cardiff University, Main Building, Park Place, Cardiff CF10 3AT, UK. E-mail: SilveriF@Cardiff.ac.uk; CatlowR@Cardiff.ac.uk\\n '),
#  Paragraph(id='art-admin', references=[], text='Received \\n 22nd September 2018\\n , Accepted 18th November 2018'),
#  Paragraph(id='wrapper', references=[], text='First published on 17th January 2019'),
#  Paragraph(id='wrapper', references=[], text='Transition metal carbides are a class of materials widely known for both their interesting physical properties and catalytic activity. In this work, we have used plane-wave DFT methods to study the interaction with increasing amounts of molecular hydrogen on the low-index surfaces of four major carbides \\xe2\\x80\\x93 TiC, VC, ZrC and NbC. Adsorption is found to be generally exothermic and occurs predominantly on the surface carbon atoms. We identify trends over the carbides and their surfaces for the energetics of the adsorption as a function of their electronic and geometrical characteristics. An ab initio thermodynamics formalism is used to study the properties of the slabs as the hydrogen coverage is increased.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n\n'),
#  Heading(id='sect236', references=[], text='Introduction'),
#  Paragraph(id='wrapper', references=['cit1', 'cit3', 'cit4'], text='\\n\nOne of the key scientific and technical challenges of the 21st century is the need to meet the global demand for energy in a clean, secure and sustainable way, by overcoming remaining issues of electricity storing and pollution. The hydrogen evolution reaction (HER) has been intensively studied as a route to produce H2 from H2O, with the primary goal of using molecular hydrogen in carbon-free fuel cells and as a reductant to recycle CO2. The HER is most effectively catalysed by Pt electrodes, which allow the reaction to be driven using a low overpotential. However, the high cost and low supply of Pt make it an impractical catalyst for global scale production of H2.\\n\n'),
#  Paragraph(id='wrapper', references=['cit6', 'cit8', 'cit12'], text='Low cost materials have been investigated in recent years with the aim of obtaining similar performances to Pt. One such avenue of research is the class of materials known as transition metal carbides (TMCs), which couple low cost and high durability with interesting catalytic properties for many reactions, as originally highlighted by the seminal work by Levy and Boudart in 1973.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=['cit13', 'cit15', 'cit11', 'cit23', 'cit25'], text='Transition metals can form carbides in a variety of structures and stoichiometries, depending on their position in the periodic table and the extent of defects in the structure. Monocarbides and non-stoichiometric carbides of early transition metals are found to have stable rock-salt bulk structures, while metals at the centre of the transition series have more complex stoichiometries and structures. These compounds combine some of the physical properties of transition metals, ionic and covalent solids, which can be further modified by tuning the amount of carbon in the lattice and the bonding character of the metal\\xe2\\x80\\x93carbon bond.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=['cit27', 'cit33', 'cit11', 'cit35'], text='The catalytic behaviour of TMCs has been investigated for a wide range of reactions, such as hydrogenation, CO2 reduction, water-gas shift, hydro-treatment and a number of processes involving hydrocarbons, including isomerization and methane reforming. For the hydrogen evolution reaction, these materials have been used with promising results as both supports for platinum electrocatalysts and as catalysts themselves, either as bulk materials or nanoparticles. However, TMC catalysts have still not seen widespread adoption in industrial processes.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=['cit27'], text='In this work, the interaction between molecular hydrogen and four TMCs from groups IV and V is studied using plane-wave Density Functional Theory (DFT) methods. TiC, ZrC, VC and NbC, all with 1:1 stoichiometry and the rock-salt structure, are modelled and cut into four different low index surfaces, i.e. the (001) and (011) surfaces and the carbon- and metal-terminations of the (111) plane. We have identified trends in the energetic and electronic effects of the H2 adsorption from which we can make predictions concerning the H2 evolution under specific conditions on the different surfaces. The metal carbides were chosen after a comprehensive review of bulk and surface properties showed that they had promising properties as potential catalysts for CO2 hydrogenation reactions. Previous experimental and computational results suggest that TiC and its immediate neighbours are good candidates for H2 evolution and CO2 reduction and could be superior to other transition metal carbides with 1:1 stoichiometries. Whilst these prior studies have clearly provided important insight, our work offers the first comprehensive theoretical study into hydrogen adsorption on all low-index surfaces of TiC, ZrC, VC and NbC.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n\n'),
#  Heading(id='sect270', references=[], text='Computational details'),
#  Paragraph(id='wrapper', references=['cit37', 'cit40', 'cit41', 'cit42', 'cit43'], text='\\n\nAll calculations have been performed within the framework of the density functional theory (DFT) as implemented in the VASP (Vienna Ab initio Software Package) code. The electronic energy was obtained using PAW (projected augmented wave) potentials and plane-wave basis sets, respectively, for core and valence electrons, using the Perdew\\xe2\\x80\\x93Burke\\xe2\\x80\\x93Ernzerhof (PBE) functional. Corrections were added to account for long-range interactions by the semi-empirical Grimme D3 dispersion method and for non-spherical contributions to the PAW potentials as incorporated in the code. All energies were converged within a cutoff of 520 eV and an electronic self-consistent field (SCF) threshold of 10\\xe2\\x88\\x925 eV. Convergence was determined using the tetrahedron method, implementing Blochl corrected smearing and in all cases spin polarization was enabled, with the only exception of the isolated H2 closed shell molecule.\\n\n'),
#  Paragraph(id='wrapper', references=['cit30'], text='The surfaces of the TMCs in the study were simulated by 2 \\xc3\\x97 2 \\xc3\\x97 3 supercell slab models generated via the METADISE code, cutting the bulk along the (001), (011) and (111) planes. Each slab has 6 atomic layers and 16 atoms per layer. The (001) and (011) surfaces are created such that they preserve the bulk stoichiometry, resulting in an equal number of carbon and metal atoms being exposed to the vacuum. Conversely, the (111) plane is parallel to carbon and metal layers, resulting in two possible surface terminations that respectively expose carbon and metal atoms in the surface. Such a protocol has been applied previously to TMCs and has been shown to describe accurately the electronic and structural properties of the (111) surfaces, as will be further discussed below. To avoid interaction along the axis perpendicular to the surface, 12 \\xc3\\x85 of vacuum were added in that direction. The 5 \\xc3\\x97 5 \\xc3\\x97 1 K-points reciprocal lattice matrix was generated using the Monkhorst\\xe2\\x80\\x93Pack method. The energy of the system was minimized by keeping the cell parameters fixed at their bulk-optimised value and allowing relaxation of all atoms, apart from those belonging to the 2 bottom layers of the TMC, which were kept fixed. The minimum energy structures were found using a built-in DIIS algorithm with a convergence force threshold of 10\\xe2\\x88\\x922 eV \\xc3\\x85\\xe2\\x88\\x921.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='The interactions between the different surfaces and hydrogen were compared using the adsorption energy (\\xce\\x94Eads) as calculated by:'),
#  Paragraph(id='wrapper', references=[], text='\\xc2\\xa0'),
#  Paragraph(id='wrapper', references=[], text='(1)'),
#  Paragraph(id='wrapper', references=[], text='where\nEslab+nH is the energy of the hydrogenated slab, Eslab and EH2 are the energies of the pristine surface and isolated H2, respectively, and n is the number of hydrogen atoms involved in the adsorption. By normalizing, we consider as \\xce\\x94Eads the adsorption energy per atom instead of the total energy change in the system. The energy of hydrogen, which is also used to calculate the chemical potential of the molecule, is calculated in a broken symmetry unit cell of 9 \\xc3\\x97 10 \\xc3\\x97 11 \\xc3\\x85, using the same parameters with which the surfaces have been investigated.\\n\n'),
#  Paragraph(id='wrapper', references=['cit44', 'cit45', 'cit47'], text='Atomic charges were calculated on specific configurations through a Bader charge analysis, as implemented by Henkelman and co-workers. The reported work functions (\\xce\\xa6) were calculated by subtracting the Fermi energy from the vacuum energy, extracted from the local potential by averaging the energy levels above the surface. The resulting \\xce\\xa6 were further used to calculate the theoretical half-cell electrode potential for the slabs, for each coverage state, as outlined in the seminal paper by Trasatti:'),
#  Paragraph(id='wrapper', references=[], text='\\xc2\\xa0'),
#  Paragraph(id='wrapper', references=[], text='(2)'),
#  Paragraph(id='wrapper', references=[], text='where\n\\xce\\xa6slab is the work function of the slab, e is the electron charge and 4.5 V is an estimate of the absolute potential of the NHE as calculated from its work function, coherently with that found in the literature.\\n\n'),
#  Paragraph(id='wrapper', references=['cit50'], text='The effect of hydrogen coverage has been further investigated by means of the ab initio thermodynamics formalism with the objective of elucidating the level of hydrogenation as a function of the chemical potential of H2 in the gas phase. The surface free energies (\\xcf\\x83) are therefore defined as follows:'),
#  Paragraph(id='wrapper', references=[], text='\\xc2\\xa0'),
#  Paragraph(id='wrapper', references=[], text='(3)'),
#  Paragraph(id='wrapper', references=[], text='where\n\\xce\\xb3 is the surface energy of the relaxed, pristine slab, E\\xce\\xb8 is the energy of the slab with coverage state \\xce\\xb8, Eclean is the energy for the pristine slab, n is the number of H atoms adsorbed on the surface and \\xce\\xbcH is their chemical potential in the gas phase. Values for the chemical potential as a function of temperature and pressure were obtained using standard statistical thermodynamics, via the formula:\n'),
#  Paragraph(id='wrapper', references=[], text='\\xc2\\xa0'),
#  Paragraph(id='wrapper', references=[], text='(4)'),
#  Paragraph(id='wrapper', references=[], text='where\nEel and ZPE are the electronic and zero point energy of the hydrogen molecule as derived from DFT, the \\xce\\x94G term is the difference in Gibbs free energy between 0 K and T at constant pressure p0 = 1 bar as calculated from the partition function of the molecule and the last term is the pressure dependency of the Gibbs free energy.\\n \\n \\n\n'),
#  Heading(id='sect345', references=[], text='Results and discussion'),
#  Paragraph(id='wrapper', references=['fn1'], text='\\n\nOur study of the H2 adsorption on these TMCs \\xe2\\x80\\x93 TiC, VC, ZrC and NbC \\xe2\\x80\\x93 first explored the stability of molecular hydrogen above a test surface, namely the (001) surface of TiC. Initially, H2 was placed 6.5 \\xc3\\x85 over the (001) surface of TiC and fully optimized, resulting in a weak long-range interaction energy of 0.05 eV. Secondly, the distance between the surface and the molecule was systematically decreased to find potential curves. Spontaneous dissociative chemisorption was observed to occur when the molecule was placed less than 2.0 \\xc3\\x85 above the topmost surface atomic plane. The dissociation happens on top of one of the surface Ti atoms, producing an intermediate in which one of hydrogens is coordinated by two Ti atoms and the other absorbs on top of a C atom. However, the most favourable adsorption is found when both H atoms absorb on top of a surface C, a feature that, as shown below, is shared by all tested systems. The same protocol was subsequently repeated on other low index surfaces as well as on other carbides leading to similar results. For full details of the hydrogen adsorption potential energy surface, please see ESI.\\n\n'),
#  Paragraph(id='wrapper', references=['cit9'], text='This result agrees with previous experimental and computational results, which show that hydrogen adsorption is dissociative on these carbides.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n\n'),
#  Heading(id='sect353', references=[], text='Hydrogen adsorption'),
#  Paragraph(id='wrapper', references=['fn1', 'tab1'], text='\\n\nHaving established the fundamental exothermicity of adsorption, adsorption sites and their respective energies were explored on all carbides. The results show clear geometric and energetical similarities between each surface plane amongst the four studied carbides. Two different adsorption geometries for the (001) surface are shown in Fig. 1; in the first the adsorbed hydrogens are located on top of a C atom (Contop site) and in the second between two metal atoms (M2-hollow site). On TiC, in the Contop site, each H atom absorbs 1.28 \\xc3\\x85 above the surface, while on the M2-hollow site, the H absorbs directly above the surface Ti. In the first case, the formation of a C\\xe2\\x80\\x93H bond is combined with a change in M\\xe2\\x80\\x93C bond distance, which increases slightly, as the dangling bonds of C are linked with the electron on hydrogen. However, this elongation is very small. Energetically, the Contop site is favoured, with \\xce\\x94Eads = \\xe2\\x88\\x920.62 eV, while the M2-hollow site shows an endothermic adsorption, with \\xce\\x94Eads = +0.38 eV. A Bader charge analysis and a density of states (DOS) calculation have been performed on both the pristine and the hydrogenated surfaces. The two analyses show how the adsorption has little effect on the electronic structure of the surface, and the former also highlights that for both adsorption sites the two adsorbed hydrogens retain one electron each. For further details on the two analyses, see ESI. Similar results in terms of geometry, surface reconstruction and charge localization were found on all other carbides, as reported in Table 1. Energetically, TiC, VC and ZrC exhibit favourable hydrogen adsorption on their (001) surfaces, while NbC showing endothermic adsorption energies on both the Contop and M2-hollow adsorption sites.\\n '),
#  Figure(id=None, references=[], caption='(a) Adsorption geometries for (001) surfaces: the M2-hollow site (left) and the Contop site (right) (b) adsorption geometries for (011) surfaces: the Contop site (left) and the M2-hollow site (right). Titanium atoms are depicted in blue, with carbon atoms and hydrogens shown in brown and grey respectively.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n\n'),
#  Table(id=None, references=[], caption='The geometric and energetic effects of the transition metal carbide on the most favourable binding site for the adsorption of one hydrogen molecule on the (001) surfaces'),
#  Paragraph(id='wrapper', references=[], text='\\n\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n \\n \\n \\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Site'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xce\\x94Eads'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n Z\\n ads\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n e\\n \\xe2\\x88\\x92\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xce\\x94Eads: adsorption energy per atom in eV. Zads: adsorption distance in \\xc3\\x85. e\\xe2\\x88\\x92: Bader charge on the adsorbed hydrogen in atomic units.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='TiC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.62'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.13'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='0.94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='VC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.17'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.14'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='0.97'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='ZrC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.74'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.34'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.01'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='NbC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='0.06'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.12'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='0.97'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=['tab2'], text='On the (011) surfaces, similar M2-hollow and Contop adsorption sites are found. On such surfaces both sites show higher \\xce\\x94Eads by 0.5\\xe2\\x80\\x931 eV compared to (001), and the adsorption on the Contop site is again the most exergonic and thus most favourable on these surfaces. Due to the conformation of the surface, the C\\xe2\\x80\\x93H distance for the Contop site surface is shorter than that of the same site on (001) and an even smaller M\\xe2\\x80\\x93C bond elongation is found, while on the M2-hollow site adsorbed hydrogen is at a greater distance from the surface. The distortion of the surface also causes the hydrogen atoms on the Contop site not to be vertically aligned with their respective carbon. The Bader charge analysis shows an equal localization of the charge between the two atoms, which as in the previous case retain their respective electrons. Table 2 shows the adsorption energies, Bader charges on hydrogens and C\\xe2\\x80\\x93H bond distances on the (011) surfaces of all four carbides.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n\n'),
#  Table(id=None, references=[], caption='The geometric and energetic effects of the transition metal carbide on the most favourable binding site for molecular hydrogen on the (011) surfaces'),
#  Paragraph(id='wrapper', references=[], text='\\n\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n \\n \\n \\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Site'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xce\\x94Eads'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n Z\\n ads\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n e\\n \\xe2\\x88\\x92\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xce\\x94Eads: adsorption energy per atom in eV. Zads: adsorption distance in \\xc3\\x85. e\\xe2\\x88\\x92: Bader charge on the adsorbed hydrogen in atomic units.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='TiC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x921.40'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.12'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.03'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='VC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x921.07'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.11'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='0.93'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='ZrC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x921.36'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.06'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.12'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='NbC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.88'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.11'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='0.89'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=['cit54', 'cit36', 'cit55'], text='The two surface terminations along the (111) plane are treated separately because of the variation in the stoichiometries of their topmost atomic layer and their resulting different surface energies. Both the metal- and carbon-terminated slab models show a dipole perpendicular to the surface, arising from the presence of alternate layers of carbon and metal atoms. However, previous studies have shown similar trends in the electronic properties of the surface on both reconstructed and unreconstructed surfaces. Moreover, experimental reports only show unreconstructed metal-terminated surfaces for the (111) plane, when this surface can be shown to be clean and free of impurities under ultravacuum conditions. For these reasons, only the unreconstructed metal and carbon terminations of the (111) plane will be considered in this study.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=['tab3'], text='On the metal-terminated (111) plane \\xe2\\x80\\x93 (111)-M from now on \\xe2\\x80\\x93 the surface atoms are arranged in a hexagonal fashion, as shown in Fig. 2. A threefold site is available for the hydrogen, which adsorbs at the barycentre of a triangle formed by 3 metal atoms, and on top of a carbon atom of the second layer of the slab, labelled as M3-hollow site. This configuration involves large adsorption energies on all carbides, up to \\xce\\x94Eads = \\xe2\\x88\\x921.99 eV on TiC. The electron-donating nature of the terminating metal layer is made clear by a Bader charge analysis of the slab, which shows 1.6 e\\xe2\\x88\\x92 on the hydrogens upon homolytic cleavage. The \\xce\\x94Eads values for all carbides and other parameters of interest related to the adsorption are reported in Table 3.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Figure(id=None, references=[], caption='Adsorption geometries for (111) surfaces: M3-hollow site on the metal terminated surface (right) and Contop site on the carbon terminated surface (left).'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n\n'),
#  Table(id=None, references=[], caption='The geometric and energetic effects of the transition metal carbide on the M3-hollow binding of molecular hydrogen on the (111)-M surfaces'),
#  Paragraph(id='wrapper', references=[], text='\\n\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n \\n \\n \\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Site'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xce\\x94Eads'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n Z\\n ads\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n e\\n \\xe2\\x88\\x92\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xce\\x94Eads: adsorption energy per atom in eV. Zads: adsorption distance in \\xc3\\x85. e\\xe2\\x88\\x92: Bader charge on the adsorbed hydrogen in atomic units.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='TiC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='M3-hollow'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x921.99'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='2.02'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.64'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='VC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='M3-hollow'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x921.17'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.56'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='ZrC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='M3-hollow'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x921.34'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='2.17'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.68'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='NbC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='M3-hollow'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x921.24'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='2.07'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.59'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=['tab4', 'cit36'], text='A different picture emerges from the calculations on the (111)-C surface. This surface termination shows instability in the presence of hydrogen, leading to a dramatic reconstruction on TiC and VC, whereby a combination of carbon atom sintering and hydro-carbon formation distorts the pristine surface geometries. However, for the two 5th period TMCs in this study, it was possible to find a minimum in the potential energy surface associated with the adsorption. In the latter cases the adsorbed hydrogen absorbs on a Contop site, similarly to that found on the (001) and (011) surfaces. However, a more exothermic reaction and a more extensive surface reconstruction of the model slab are involved. Table 4 summarizes these results, which are consistent with the previously reported energetic preference for metal termination on the (111) surface of these two carbides, as deduced from surface energies.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n\n'),
#  Table(id=None, references=[], caption='The geometric and energetic effects of the transition metal carbide on the Contop binding of molecular hydrogen on the (111)-C surfaces'),
#  Paragraph(id='wrapper', references=[], text='\\n\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n \\n \\n \\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Site'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xce\\x94Eads'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n Z\\n ads\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n e\\n \\xe2\\x88\\x92\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xce\\x94Eads: adsorption energy per atom in eV. Zads: adsorption distance in \\xc3\\x85. e\\xe2\\x88\\x92: Bader charge on the adsorbed hydrogen in atomic units.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='TiC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='N/D'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\x94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\x94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\x94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='VC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='N/D'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\x94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\x94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\x94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='ZrC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x922.01'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.10'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='0.88'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='NbC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x921.69'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1.10'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='0.83'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=['cit36'], text='The binding energies obtained for hydrogen adsorption can be compared with previous studies on the same surfaces, highlighting correlations between the surface properties and their reactivity. The reported surface energies and d-band positions for these materials show trends along the rows and down the groups that correlate well to their reactivity. The trends over the surfaces for a single carbide and over the same face of each carbide show an inverse correlation with the \\xce\\x94Eads which, despite some discrepancies, can be considered a good descriptor of the activity of the carbide surface considered. Fig. 3 shows how, for the (001) surfaces of all carbides as well as all four surfaces of ZrC, a less negative d-band centre corresponds to a more exothermic hydrogen adsorption.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Figure(id=None, references=[], caption='Correlation between \\xce\\x94Eads of a single hydrogen molecule (red dots) and the d-band centres (blue columns) on different carbides and surfaces. (top) Shows the values for ZrC over the four investigated surfaces, (bottom) shows the values for (001) surfaces over the four carbides.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n\n'),
#  Heading(id='sect658', references=[], text='Higher hydrogen loadings'),
#  Paragraph(id='wrapper', references=[], text='\\n\nIn this section, our approach is to load hydrogen atoms up to monolayer (ML) coverage. In the previous section, 16 adsorption sites had been identified on each model slab: on the slab representing (001) and (011) surfaces these are equally divided between Contop and M2-hollow, while on those representing the two terminations of the (111) surfaces either 16 Contop or 16 M3-hollow sites are present. Therefore, loadings of 4, 8 and 16 hydrogen atoms over the 16 surface adsorption sites are investigated, and the corresponding coverage and surface properties are then evaluated for each system.\\n\n'),
#  Paragraph(id='wrapper', references=['tab5'], text='On the (001) surface termination, adsorption of 4 and 8 H produces a decrease in adsorption energy per atom on each of the four carbides in study. The adsorbed hydrogens all absorb on the 8 Contop sites. Subsequent adsorption of H2 on the surface is expected to occur on the M2-hollow site, which has been shown previously to be endothermic. However, steric effects prevent these sites from being available. Thus we find that on the carbides of the 5th period, ZrC and NbC, hydrogen adsorbs on the more endothermic Montop sites, resulting in a positive total adsorption energy (see Table 5 and Fig. 4). On the carbides of the 4th period, TiC and VC, it was not possible to find a stable minimum for the adsorption on such sites for the (001) surface.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n\n'),
#  Table(id=None, references=[], caption='The energetic effects of the transition metal carbide on the hydrogen loading on the (001) surfaces'),
#  Paragraph(id='wrapper', references=[], text='\\n\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n \\n \\n \\n \\n \\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n nH'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n \\xce\\xb8\\n '),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Site'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='TiC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='VC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='ZrC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='NbC'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n nH: number of H atoms on the surface of the slab. \\xce\\xb8: coverage, as a fraction of a monolayer. TiC, VC, ZrC, NbC: \\xce\\x94Eads on each carbide in eV.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='2'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xc2\\xbc'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.62'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.17'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.73'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='+0.06'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='4'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xc2\\xbd'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.52'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.14'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.62'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='+0.04'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='8'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='1'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.35'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.06'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x88\\x920.38'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='+0.09'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='16'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='2'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='Contop + Montop'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\x94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\x94'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='+0.09'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='+0.31'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n '),
#  Figure(id=None, references=[], caption='The graph shows the correlation between hydrogen loading and \\xce\\x94Eads (blue) and between hydrogen loading and \\xce\\xa6 (red) on the TiC(001) surface.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='For these reasons we consider that the chemisorption of H on Contop defines the monolayer on all (001) surfaces in our study, even if these are only half of the stable minima found on the potential energy surface for chemisorbed hydrogen. Within our model slabs, this translates in having \\xce\\xb8 = 1 when 8 H atoms are adsorbed.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
# ...
#  Paragraph(id='wrapper', references=[], text='Although these findings help our understanding of the interaction between transition metal carbides and hydrogen, future work is needed both experimentally, to prove those findings, and theoretically, to investigate the consequences of the observed trends, including the feasibility of CO2 reduction over the surfaces of these carbides.'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n\n'),
#  Heading(id='sect994', references=[], text='Conflicts of interest'),
#  Paragraph(id='wrapper', references=[], text='\\n\nThere are no conflicts to declare.\\n \\n \\n\n'),
#  Heading(id='sect998', references=[], text='Acknowledgements'),
#  Paragraph(id='wrapper', references=[], text="\\n\nFS thanks the Cardiff University School of Chemistry for a fully funded PhD scholarship. This work was funded as part of an EPSRC low carbon fuels grant (EP/N009533/1). Computing facilities for this work were provided by ARCCA at Cardiff University, HPC Wales, and through our membership of the UK\\'s Materials Chemistry Consortium (MCC). The MCC is funded by EPSRC (EP/F067496). Information on the data underpinning the results presented here, including how to access them, can be found in the Cardiff University data catalogue at http://doi.org/10.17035/d.2018.0064126200.\\n \\n \n"),
#  Heading(id='sect997', references=[], text='Notes and references'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit1', references=[], text='\\n R. Nakicenovic and N. Swart, Intergovenmental Panel on Climate Change, Washington, DC, 2014\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit2', references=[], text='Fourth National Climate Assessment, Vol. I: the Climate Science Special Report, US Department of Energy, 2017.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit3', references=[], text='N. S. Lewis and D. G. Nocera, Proc. Natl. Acad. Sci. U. S. A., 2006, 103, 15729\\xe2\\x80\\x9315735\\xc2\\xa0CrossRef\\xc2\\xa0CAS\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit4', references=[], text='C. Ling, L. Shi, Y. Ouyang and J. Wang, Chem. Mater., 2016, 28, 9026\\xe2\\x80\\x939032\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit5', references=[], text='B. E. Conway and B. V. Tilak, Electrochim. Acta, 2002, 47, 3571\\xe2\\x80\\x933594\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit6', references=[], text='W. Cui, Q. Liu, N. Cheng, A. M. Asiri and X. Sun, Chem. Commun., 2014, 50, 9340\\xe2\\x80\\x939342\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit7', references=[], text='X. Guo, G. Cao, F. Ding, X. Li, S. Zhen, Y. Xue, Y. Yan, T. Liu and K. Sun, J. Mater. Chem. A, 2015, 3, 5041\\xe2\\x80\\x935046\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit8', references=[], text='K. Z. Qi, G. C. Wang and W. J. Zheng, Surf. Sci., 2013, 614, 53\\xe2\\x80\\x9363\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit9', references=[], text='W.-F. Chen, J. T. Muckerman and E. Fujita, Chem. Commun., 2013, 49, 8896\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit10', references=[], text='K. Oshikawa, M. Nagai and S. Omi, J. Phys. Chem. B, 2001, 105, 9124\\xe2\\x80\\x939131\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit11', references=[], text='A. L. Stottlemyer, T. G. Kelly, Q. Meng and J. G. Chen, Surf. Sci. Rep., 2012, 67, 201\\xe2\\x80\\x93232\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit12', references=[], text='R. B. Levy and M. Boudart, Science, 1973, 181, 547\\xe2\\x80\\x93549\\xc2\\xa0CrossRef\\xc2\\xa0CAS\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit13', references=[], text='J. H\\xc3\\xa4glund, A. Fernndez Guillermet, G. Grimvall and M. K\\xc3\\xb6rling, Phys. Rev. B: Condens. Matter Mater. Phys., 1993, 48, 11685\\xe2\\x80\\x9311691\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit14', references=[], text='\\n L. Toth, Transition Metal Carbides and Nitrides, Academic Press, New York and London, 1971\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit15', references=[], text='A. Neckel, P. Rastl, R. Eibler, P. Weinberger and K. Schwarz, J. Phys. C: Solid State Phys., 2001, 9, 579\\xe2\\x80\\x93592\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit16', references=[], text='A. Kelly and D. Rowcliffe, Phys. Status Solidi, 1966, 14, K29\\xe2\\x80\\x93K33\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit17', references=[], text='X. Fan, B. Chen, M. Zhang, D. Li, Z. Liu and C. Xiao, Mater. Des., 2016, 112, 282\\xe2\\x80\\x93289\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit18', references=[], text='D. W. Lee, S. V. Alexandrovskii and B. K. Kim, Mater. Lett., 2004, 58, 1471\\xe2\\x80\\x931474\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit19', references=[], text='S. Tjong, Mater. Sci. Eng., R, 2000, 29, 49\\xe2\\x80\\x93113\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit20', references=[], text='P. S. Henderson, Surf. Coat. Technol., 2003, 174\\xe2\\x80\\x93175, 720\\xe2\\x80\\x93724\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit21', references=[], text='W. Yang, S. Rehman, X. Chu, Y. Hou and S. Gao, ChemNanoMat, 2015, 13, 76\\xe2\\x80\\x93398\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit22', references=[], text='S. R. Shatynski, Oxid. Met., 1979, 13, 105\\xe2\\x80\\x93118\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit23', references=[], text='H. H. Hwu and J. G. Chen, Chem. Rev., 2005, 105, 185\\xe2\\x80\\x93212\\xc2\\xa0CrossRef\\xc2\\xa0CAS\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit24', references=[], text='F. Vines, C. Sousa, P. Liu, J. A. Rodriguez and F. Illas, J. Chem. Phys., 2005, 122, 174709\\xc2\\xa0CrossRef\\xc2\\xa0CAS\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit25', references=[], text='L. Ramqvist, K. Hamrin, G. Johansson, A. Fahlman and C. Nordling, J. Phys. Chem. Solids, 1969, 30, 1835\\xe2\\x80\\x931847\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit26', references=[], text='K. Schwarz, Crit. Rev. Solid State Mater. Sci., 1987, 13, 211\\xe2\\x80\\x93257\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit27', references=[], text='L. Delannoy, J. M. Giraudon, P. Granger, L. Leclercq and G. Leclercq, Catal. Today, 2000, 59, 231\\xe2\\x80\\x93240\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit28', references=[], text='L. K. Ono, D. Sudfeld and B. Roldan Cuenya, Surf. Sci., 2006, 600, 5041\\xe2\\x80\\x935050\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit29', references=[], text='C. Kunkel, F. Vi\\xc3\\xb1es and F. Illas, Energy Environ. Sci., 2016, 9, 141\\xe2\\x80\\x93144\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit30', references=[], text='S. Posada-P\\xc3\\xa9rez, F. Vi\\xc3\\xb1es, P. J. Ramirez, A. B. Vidal, J. A. Rodriguez and F. Illas, Phys. Chem. Chem. Phys., 2014, 16, 14912\\xe2\\x80\\x9314921\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit31', references=[], text='M. D. Porosoff, S. Kattel, W. Li, P. Liu and J. G. Chen, Chem. Commun., 2015, 51, 6988\\xe2\\x80\\x936991\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit32', references=[], text='M. D. Porosoff, X. Yang, J. A. Boscoboinik and J. G. Chen, Angew. Chem., Int. Ed., 2014, 53, 6705\\xe2\\x80\\x936709\\xc2\\xa0CrossRef\\xc2\\xa0CAS\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit33', references=[], text='D. V. Esposito, S. T. Hunt, A. L. Stottlemyer, K. D. Dobson, B. E. Mccandless, R. W. Birkmire and J. G. Chen, Angew. Chem., 2010, 9859\\xe2\\x80\\x939862\\xc2\\xa0CrossRef\\xc2\\xa0CAS\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit34', references=[], text='A. L. Tom\\xc3\\xa1s-Garc\\xc3\\xada, J. O. Jensen, N. J. Bjerrum and Q. Li, Electrochim. Acta, 2014, 137, 639\\xe2\\x80\\x93646\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit35', references=[], text='T. Xiao, A. P. E. York, K. S. Coleman, J. B. Claridge, J. Sloan, J. Charnock and M. L. H. Green, J. Mater. Chem., 2001, 11, 3094\\xe2\\x80\\x933098\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit36', references=[], text='M. G. Quesne, A. Roldan, N. H. de Leeuw and C. R. A. Catlow, Phys. Chem. Chem. Phys., 2018, 20, 6905\\xe2\\x80\\x936916\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit37', references=[], text='G. Kresse and J. Furthmiiller, Comput. Mater. Sci., 1996, 6, 15\\xe2\\x80\\x9350\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit38', references=[], text='G. Kresse and J. Hafner, Phys. Rev. B: Condens. Matter Mater. Phys., 1993, 47, 558\\xe2\\x80\\x93561\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit39', references=[], text='G. Kresse and J. Furthm\\xc3\\xbcller, Phys. Rev. B: Condens. Matter Mater. Phys., 1996, 54, 11169\\xe2\\x80\\x9311186\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit40', references=[], text='P. E. Bl\\xc3\\xb6chl, Phys. Rev. B: Condens. Matter Mater. Phys., 1994, 50, 17953\\xe2\\x80\\x9317979\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit41', references=[], text='J. P. Perdew, K. Burke and M. Ernzerhof, Phys. Rev. Lett., 1996, 77, 3865\\xe2\\x80\\x933868\\xc2\\xa0CrossRef\\xc2\\xa0CAS\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit42', references=[], text='S. Grimme, J. Antony, S. Ehrlich and H. Krieg, J. Chem. Phys., 2010, 132, 154104\\xc2\\xa0CrossRef\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit43', references=[], text='P. E. Bl\\xc3\\xb6chl, O. Jepsen and O. K. Andersen, Phys. Rev. B: Condens. Matter Mater. Phys., 1994, 49, 16223\\xe2\\x80\\x9316233\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit44', references=[], text='\\n R. F. Bader, Atoms in molecules: a quantum theory, International series of monographs on chemistry, 1990, vol. 22\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit45', references=[], text='G. Henkelman, A. Arnaldsson and H. J\\xc3\\xb3nsson, Comput. Mater. Sci., 2006, 36, 354\\xe2\\x80\\x93360\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit46', references=[], text='W. Tang, E. Sanville and G. Henkelman, J. Phys.: Condens. Matter, 2009, 21, 084204\\xc2\\xa0CrossRef\\xc2\\xa0CAS\\xc2\\xa0.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit47', references=[], text='S. Trasatti, Electrochim. Acta, 1991, 36, 1659\\xe2\\x80\\x931667\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit48', references=[], text='E. Sk\\xc3\\xbalason, G. S. Karlberg, J. Rossmeisl, T. Bligaard, J. Greeley, H. J\\xc3\\xb3nsson and J. K. N\\xc3\\xb8rskov, Phys. Chem. Chem. Phys., 2007, 9, 3241\\xe2\\x80\\x933250\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit49', references=[], text='J. Rossmeisl, E. Sk\\xc3\\xbalason, M. E. Bj\\xc3\\xb6rketun, V. Tripkovic and J. K. N\\xc3\\xb8rskov, Chem. Phys. Lett., 2008, 466, 68\\xe2\\x80\\x9371\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit50', references=[], text='X.-G. Wang, W. Weiss, S. K. Shaikhutdinov, M. Ritter, M. Petersen, F. Wagner, R. Schogl and M. Scheffl, Phys. Rev. Lett., 1998, 81, 1038\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit51', references=[], text='D. Santos-Carballal, A. Roldan, R. Grau-Crespo and N. H. de Leeuw, Phys. Chem. Chem. Phys., 2014, 16, 21082\\xe2\\x80\\x9321097\\xc2\\xa0RSC.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit52', references=[], text='Y. Zhao, A. C. Dillon, Y. H. Kim, M. J. Heben and S. B. Zhang, Chem. Phys. Lett., 2006, 425, 273\\xe2\\x80\\x93277\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit53', references=[], text='S. Trasatti, J. Electroanal. Chem., 1972, 39, 163\\xe2\\x80\\x93184\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit54', references=[], text='P. W. Tasker, J. Phys. C: Solid State Phys., 1979, 12, 4977\\xe2\\x80\\x934984\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit55', references=[], text='T. Aizawa, W. Hayami, R. Souda, S. Otani and Y. Ishizawa, Surf. Sci., 1997, 381, 157\\xe2\\x80\\x93164\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit56', references=[], text='W. Hayami, R. Souda, T. Aizawa, S. Otani and Y. Ishizawa, Phys. Rev. B: Condens. Matter Mater. Phys., 1993, 47, 13752\\xe2\\x80\\x9313758\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit57', references=[], text='R. Souda, T. Aizawa, S. Otani and Y. Ishizawa, Surf. Sci., 1990, 232, 219\\xe2\\x80\\x93227\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit58', references=[], text='W. Hayami, \\n et al.\\n , Surf. Sci., 1992, 276, 299\\xe2\\x80\\x93307\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit59', references=[], text='S. Posada-P\\xc3\\xa9rez, F. Vi\\xc3\\xb1es, R. Valero, J. A. Rodriguez and F. Illas, Surf. Sci., 2017, 656, 24\\xe2\\x80\\x9332\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit60', references=[], text='V. Tripkovic, M. E. Bj\\xc3\\xb6rketun, E. Sk\\xc3\\xbalason and J. Rossmeisl, Phys. Rev. B: Condens. Matter Mater. Phys., 2011, 84, 115452\\xc2\\xa0CrossRef.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Citation(id='cit61', references=[], text='J. K. Norskov, J. Electrochem. Soc., 2005, 152, J23\\xe2\\x80\\x93J26\\xc2\\xa0CrossRef\\xc2\\xa0CAS.'),
#  Paragraph(id='wrapper', references=[], text='\\n\n'),
#  Paragraph(id='wrapper', references=[], text='\\n \\n \\n \\n \\n \\n\n'),
#  Heading(id=None, references=[], text='Footnote'),
#  Paragraph(id='wrapper', references=[], text='\\xe2\\x80\\xa0 Electronic supplementary information (ESI) available. See DOI: 10.1039/c8cp05975f'),
#  Paragraph(id='wrapper', references=[], text='This journal is \\xc2\\xa9 the Owner Societies 2019')]

# %% [markdown]
# A paragraph in the document can be accessed using an index, as follows.

# %%
# access an element on the list 
# the fifth element is the article title
para = doc.elements[4]
para
# Out:
# Title(id='sect187', references=['fn1'], text='Hydrogen adsorption on transition metal carbides: a DFT study')

# %% [markdown]
# Each element can be further explored as it is divided in sentences and tokens (not words because numbers, symbols, and punctuation characters are also considered tokens)

# %%
print(para)
print("Sentences:", len(para.sentences))
print("Tokens:", para.tokens)
print("Tokens:", len(para.tokens))
print("Tokens:", len(para.tokens[0]))
# Out:
# Hydrogen adsorption on transition metal carbides: a DFT study
# Sentences: 1
# Tokens: [[Token('Hydrogen', 0, 8), Token('adsorption', 9, 19), Token('on', 20, 22), Token('transition', 23, 33), Token('metal', 34, 39), Token('carbides', 40, 48), Token(':', 48, 49), Token('a', 50, 51), Token('DFT', 52, 55), Token('study', 56, 61)]]
# Tokens: 1
# Tokens: 10

# %% [markdown]
# CDE also creates a special list of chemical entities (elements, compounds, types, etc.). These can be accessed as the cems list. The numbers next to each entity name indicate the position of the element in the text (start and end character)

# %%
doc.cems
# Out:
# [Span('hydrogens', 726, 735),
#  Span('hydrogens', 374, 383),
#  Span('carbon', 463, 469),
#  Span('carbon', 111, 117),
#  Span('C8CP05975F\\n(Paper)\\nPhys', 21, 46),
#  Span('transition metal carbides', 23, 48),
#  Span('hydro-carbon', 249, 261),
#  Span('carbide', 347, 354),
#  Span('TiC', 480, 483),
#  Span('ZrC', 461, 464),
#  Span('TiC', 284, 287),
#  Span('hydrogen', 247, 255),
#  Span('hydrogen', 691, 699),
#  Span('hydrogen', 375, 383),
#  Span('TiC', 265, 268),
#  Span('hydrogen', 103, 111),
#  Span('hydrogens', 160, 169),
#  Span('Pt', 486, 488),
#  Span('TiC', 638, 641),
#  Span('VC(001)', 1043, 1050),
#  Span('hydrogens', 929, 938),
#  Span('transition metal carbides', 74, 99),
#  Span('carbide', 143, 150),
#  Span('ZrC', 893, 896),
#  Span('hydrogen', 14, 22),
#  Span('hydrogen', 846, 854),
#  Span('VC', 0, 2),
#  Span('hydrogens', 1389, 1398),
#  Span('hydrogen', 526, 534),
#  Span('VC', 108, 110),
#  Span('H', 309, 310),
#  Span('C\\xe2\\x80\\x93H', 682, 696),
#  Span('TiC', 103, 106),
#  Span('carbide', 394, 401),
#  Span('H', 603, 604),
#  Span('ZrC', 1645, 1648),
#  Span('TiC', 186, 189),
#  Span('carbide', 585, 592),
#  Span('TiC', 161, 164),
#  Span('hydrogen', 7, 15),
#  Span('hydrogen', 478, 486),
#  Span('hydrogen', 1182, 1190),
#  Span('hydrogen', 104, 112),
#  Span('hydrogens', 260, 269),
#  Span('TMCs', 27, 31),
#  Span('TMCs', 43, 47),
#  Span('ZrC(001)', 888, 896),
#  Span('\\n nH', 0, 5),
#  Span('H2', 530, 532),
#  Span('ZrC(111)-M', 460, 470),
#  Span('N/D', 0, 3),
#  Span('transition metal carbides', 965, 990),
#  Span('TMCs', 346, 350),
#  Span('H2', 900, 902),
#  Span('carbon', 387, 393),
#  Span('carbon', 563, 569),
#  Span('H2O', 329, 332),
#  Span('hydrogens', 653, 662),
#  Span('hydrogen', 1170, 1178),
#  Span('TiC', 1197, 1200),
#  Span('SilveriF', 98, 106),
#  Span('ZrC', 0, 3),
#  Span('TiC(001)', 920, 928),
#  Span('hydrogen', 137, 145),
#  Span('platinum', 365, 373),
#  Span('ZrC', 166, 169),
#  Span('carbides', 135, 143),
#  Span('hydrogen', 77, 85),
#  Span('CO2', 440, 443),
#  Span('CO2', 756, 759),
#  Span('CO2', 920, 923),
#  Span('carbon', 431, 437),
#  Span('methane', 234, 241),
#  Span('\\xce\\x94Eads', 0, 12),
#  Span('TiC', 196, 199),
#  Span('hydrogen', 149, 157),
#  Span('H', 522, 523),
#  Span('Titanium', 201, 209),
#  Span('hydrogen', 346, 354),
#  Span('hydrogen', 474, 482),
#  Span('Hydrogen', 0, 8),
#  Span('TiC', 318, 321),
#  Span('VC', 323, 325),
#  Span('carbides', 862, 870),
#  Span('carbon', 342, 348),
#  Span('carbon', 220, 226),
#  Span('transition metal carbide', 29, 53),
#  Span('hydrogen', 1148, 1156),
#  Span('carbon', 709, 715),
#  Span('ZrC', 115, 118),
#  Span('VC', 66, 68),
#  Span('ZrC', 327, 330),
#  Span('hydrogen', 118, 126),
#  Span('hydrogens', 147, 156),
#  Span('carbide', 433, 440),
#  Span('hydrogen', 534, 542),
#  Span('hydrogen', 1257, 1265),
#  Span('hydrocarbons', 192, 204),
#  Span('hydrogen', 209, 217),
#  Span('H2', 903, 905),
#  Span('hydrogen', 131, 139),
#  Span('hydrogen', 195, 203),
#  Span('hydrogen', 40, 48),
#  Span('hydrogen', 229, 237),
#  Span('hydrogen', 757, 765),
#  Span('hydrogen', 364, 372),
#  Span('(111)-M', 103, 110),
#  Span('Transition metal carbides', 0, 25),
#  Span('\\n \\n', 0, 5),
#  Span('hydrogen', 89, 97),
#  Span('hydrogen', 624, 632),
#  Span('carbon', 223, 229),
#  Span('hydrogen', 368, 376),
#  Span('H2', 466, 468),
#  Span('H', 868, 869),
#  Span('carbon', 174, 180),
#  Span('H2', 321, 323),
#  Span('Pt', 607, 609),
#  Span('carbon', 368, 374),
#  Span('carbon', 560, 566),
#  Span('ZrC', 292, 295),
#  Span('ZrC', 1202, 1205),
#  Span('carbon', 427, 433),
#  Span('TiC', 885, 888),
#  Span('VC', 111, 113),
#  Span('Ti', 674, 676),
#  Span('PBE', 381, 384),
#  Span('(111)-C', 57, 64),
#  Span('TiC(011)', 447, 455),
#  Span('carbon', 769, 775),
#  Span('H2', 229, 231),
#  Span('\\n \\xce\\xb8\\n', 0, 13),
#  Span('VC', 1638, 1640),
#  Span('TiC', 846, 849),
#  Span('carbon', 292, 298),
#  Span('carbides', 469, 477),
#  Span('hydrogen', 45, 53),
#  Span('TiC', 106, 109),
#  Span('TiC', 496, 499),
#  Span('hydrogen', 497, 505),
#  Span('TiC', 1633, 1636),
#  Span('H2', 20, 22),
#  Span('H2', 212, 214),
#  Span('hydrogen', 44, 52),
#  Span('TiC', 441, 444),
#  Span('carbon', 570, 576),
#  Span('H2', 123, 125),
#  Span('9 \\xc3\\x97 10 \\xc3\\x97 11 \\xc3\\x85', 476, 510),
#  Span('hydrogen', 93, 101),
#  Span('hydrogen', 605, 613),
#  Span('hydrogen', 48, 56),
#  Span('hydrogen', 1124, 1132),
#  Span('hydrogen', 800, 808),
#  Span('hydrogen', 324, 332),
#  Span('H2', 914, 916),
#  Span('TMCs', 202, 206),
#  Span('TMCs', 66, 70),
#  Span('Monocarbides', 178, 190),
#  Span('carbon', 343, 349),
#  Span('H', 157, 158),
#  Span('hydrogen', 106, 114),
#  Span('hydrogen', 330, 338),
#  Span('Perdew\\xe2\\x80\\x93Burke\\xe2\\x80\\x93Ernzerhof', 335, 379),
#  Span('ZrC', 70, 73),
#  Span('Eslab', 6, 11),
#  Span('transition metals', 232, 249),
#  Span('CO2', 108, 111),
#  Span('ZrC(111)-M', 515, 525),
#  Span('TiC', 492, 495),
#  Span('Pt', 108, 110),
#  Span('TiC', 0, 3),
#  Span('hydrogen', 261, 269),
#  Span('hydrogens', 636, 645),
#  Span('ZrC', 175, 178),
#  Span('nH', 12, 14),
#  Span('transition metal carbide', 43, 67),
#  Span('hydrogen', 439, 447),
#  Span('hydrogen', 66, 74),
#  Span('hydrogen', 130, 138),
#  Span('hydrogen', 770, 778),
#  Span('TiC', 61, 64),
#  Span('H', 56, 57),
#  Span('C\\xe2\\x80\\x93H', 943, 957),
#  Span('TMCs', 646, 650),
#  Span('ZrC', 112, 115),
#  Span('NbC', 469, 472),
#  Span('ZrC', 702, 705),
#  Span('carbon', 325, 331),
#  Span('transition metals', 463, 480),
#  Span('Ti', 640, 642),
#  Span('Hydrogen adsorption', 0, 19),
#  Span('hydrogen', 271, 279),
#  Span('carbides', 540, 548),
#  Span('carbides', 577, 585),
#  Span('(111)-C', 85, 92),
#  Span('carbon', 137, 143),
#  Span('transition metal carbides', 175, 200),
#  Span('hydrogen', 236, 244),
#  Span('hydrogen', 136, 144),
#  Span('hydrogen', 34, 42),
#  Span('Ti', 758, 760),
#  Span('hydrogen', 61, 69),
#  Span('hydrogen', 505, 513),
#  Span('hydrogen', 52, 60),
#  Span('hydrogen', 164, 172),
#  Span('hydrogen', 1668, 1676),
#  Span('CO2', 286, 289),
#  Span('TMCs', 20, 24),
#  Span('H', 197, 198),
#  Span('H', 17, 18),
#  Span('carbon', 243, 249),
#  Span('H2', 217, 219),
#  Span('carbon', 120, 126),
#  Span('H2.\\n', 673, 678),
#  Span('NbC', 0, 3)]

# %% [markdown]
# The cems list contains all the occurrences of chemical entities, so there are repetitions. CDE provides the serialize  operation for summarising all entities, joining together abreviations, and capitalised or uncapitalised occurrences.

# %%
serialised=doc.records.serialize()
len(serialised)
# Out:
# 47

# %%
serialised
# Out:
# [{'names': ['C8CP05975F\\n(Paper)\\nPhys']},
#  {'names': ['SilveriF']},
#  {'names': ['H2O']},
#  {'names': ['H2.\\n'], 'roles': ['product']},
#  {'names': ['Monocarbides']},
#  {'names': ['hydrocarbons']},
#  {'names': ['methane']},
#  {'names': ['platinum']},
#  {'names': ['TiC, ZrC']},
#  {'names': ['carbon-']},
#  {'names': ['Perdew\\xe2\\x80\\x93Burke\\xe2\\x80\\x93Ernzerhof', 'PBE']},
#  {'names': ['Eslab+nH']},
#  {'names': ['9 \\xc3\\x97 10 \\xc3\\x97 11 \\xc3\\x85']},
#  {'names': ['Hydrogen adsorption']},
#  {'names': ['Titanium']},
#  {'names': ['hydro-carbon']},
#  {'names': ['TiC(011)']},
#  {'names': ['ZrC(001)']},
#  {'names': ['TiC(001)']},
#  {'names': ['VC(001)']},
#  {'names': ['(111)-M']},
#  {'names': ['Pt']},
#  {'names': ['transition metals']},
#  {'names': ['Ti']},
#  {'names': ['C\\xe2\\x80\\x93H']},
#  {'names': ['(111)-C']},
#  {'names': ['N / D']},
#  {'names': ['ZrC(111)-M']},
#  {'names': ['\\n nH']},
#  {'names': ['\\n \\xce\\xb8\\n']},
#  {'names': ['TiC, VC']},
#  {'names': ['CO2']},
#  {'names': ['\\xce\\x94Eads']},
#  {'names': ['carbides']},
#  {'names': ['carbide']},
#  {'names': ['transition metal carbide']},
#  {'names': ['TMCs', 'transition metal carbides', 'Transition metal carbides']},
#  {'names': ['H2']},
#  {'names': ['hydrogens']},
#  {'names': ['\\n \\n']},
#  {'names': ['NbC']},
#  {'names': ['VC']},
#  {'names': ['H']},
#  {'names': ['carbon']},
#  {'names': ['TiC']},
#  {'names': ['ZrC']},
#  {'names': ['hydrogen', 'Hydrogen']}]
