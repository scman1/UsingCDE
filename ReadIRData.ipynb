# %% [markdown]
# # Reading IR DATA from PDF Documents
#
# This section contains a modified example shown based on the [reading documents page](http://chemdataextractor.org/docs/reading) of the Chem Data Extractor (CDE) documentation.
# The example uses the IR Parser to try to extract data from documents (if it is present).
#
# The first part just tries to replicate the results of the test cases from the [test pages](https://github.com/CambridgeMolecularEngineering/chemdataextractor/blob/master/tests/test_parse_ir.py).

# %%
# libraries for accessing sentences and for parsing IR data
from chemdataextractor.doc.text import Sentence
from chemdataextractor.parse.ir import ir, IrParser

def ir_parse_print(input):
    print("Input text:\n", input)
    s = Sentence(input)
    for c in IrParser().parse(s.tagged_tokens):
        print("Parsed IR Data:\n " ,c.serialize())

#test 1
text = 'IR (ATR): ṽ [cm−1] 3024 (w), 2980 (w), 2918 (w), 1601 (w), 1485 (m), 1460 (m), 1438 (w), 1358 (w), ' \
    '1290 (w), 1188 (w), 1115 (w), 1002 (m), 954 (m), 912 (w), 853 (m), 814 (s), 793 (s), 762 (s), 739 (m), ' \
    '687 (s), 671 (m).'
ir_parse_print(text)
    
#test 2    
text = 'IR (KBr/cm–1): 4321, 2222, 1734, 1300, 1049, 777, 620.'
ir_parse_print(text)

#test 3
text = 'FTIR (KBr): ν/cm‒1 3315, 3002, 1630, 1593 (νCH=N), 1251;'
ir_parse_print(text)

#test 4
text = 'IR-ATR:  3380, 3190,  2973, 2873, 1669, 1646, 1602, 1495, 1178, 828 cm-1.'
ir_parse_print(text)

# the type of sentences in the article with band data
from_article = "Nicotine: FT-IR (KBr, cm-1): ν = 3025, 2970, 2870, 1691, 1677, 904, 717."
ir_parse_print(from_article)
from_article = "[MBNT]Cl: FT-IR (KBr, cm-1): ν =3412, 3043, 2958, 1632, 1610, 1451, 1197, 916, 703, 472"
ir_parse_print(from_article)
# Out:
# Input text:
#  IR (ATR): ṽ [cm−1] 3024 (w), 2980 (w), 2918 (w), 1601 (w), 1485 (m), 1460 (m), 1438 (w), 1358 (w), 1290 (w), 1188 (w), 1115 (w), 1002 (m), 954 (m), 912 (w), 853 (m), 814 (s), 793 (s), 762 (s), 739 (m), 687 (s), 671 (m).
# Parsed IR Data:
#   {'ir_spectra': [{'solvent': 'ATR', 'peaks': [{'value': '3024', 'units': '[cm−1]', 'strength': 'w'}, {'value': '2980', 'units': '[cm−1]', 'strength': 'w'}, {'value': '2918', 'units': '[cm−1]', 'strength': 'w'}, {'value': '1601', 'units': '[cm−1]', 'strength': 'w'}, {'value': '1485', 'units': '[cm−1]', 'strength': 'm'}, {'value': '1460', 'units': '[cm−1]', 'strength': 'm'}, {'value': '1438', 'units': '[cm−1]', 'strength': 'w'}, {'value': '1358', 'units': '[cm−1]', 'strength': 'w'}, {'value': '1290', 'units': '[cm−1]', 'strength': 'w'}, {'value': '1188', 'units': '[cm−1]', 'strength': 'w'}, {'value': '1115', 'units': '[cm−1]', 'strength': 'w'}, {'value': '1002', 'units': '[cm−1]', 'strength': 'm'}, {'value': '954', 'units': '[cm−1]', 'strength': 'm'}, {'value': '912', 'units': '[cm−1]', 'strength': 'w'}, {'value': '853', 'units': '[cm−1]', 'strength': 'm'}, {'value': '814', 'units': '[cm−1]', 'strength': 's'}, {'value': '793', 'units': '[cm−1]', 'strength': 's'}, {'value': '762', 'units': '[cm−1]', 'strength': 's'}, {'value': '739', 'units': '[cm−1]', 'strength': 'm'}, {'value': '687', 'units': '[cm−1]', 'strength': 's'}, {'value': '671', 'units': '[cm−1]', 'strength': 'm'}]}]}
# Input text:
#  IR (KBr/cm–1): 4321, 2222, 1734, 1300, 1049, 777, 620.
# Parsed IR Data:
#   {'ir_spectra': [{'solvent': 'KBr', 'peaks': [{'value': '4321', 'units': 'cm–1'}, {'value': '2222', 'units': 'cm–1'}, {'value': '1734', 'units': 'cm–1'}, {'value': '1300', 'units': 'cm–1'}, {'value': '1049', 'units': 'cm–1'}, {'value': '777', 'units': 'cm–1'}, {'value': '620', 'units': 'cm–1'}]}]}
# Input text:
#  FTIR (KBr): ν/cm‒1 3315, 3002, 1630, 1593 (νCH=N), 1251;
# Parsed IR Data:
#   {'ir_spectra': [{'solvent': 'KBr', 'peaks': [{'value': '3315', 'units': 'cm‒1'}, {'value': '3002', 'units': 'cm‒1'}, {'value': '1630', 'units': 'cm‒1'}, {'value': '1593', 'units': 'cm‒1', 'bond': 'νCH = N'}, {'value': '1251', 'units': 'cm‒1'}]}]}
# Input text:
#  IR-ATR:  3380, 3190,  2973, 2873, 1669, 1646, 1602, 1495, 1178, 828 cm-1.
# Parsed IR Data:
#   {'ir_spectra': [{'peaks': [{'value': '3380', 'units': 'cm-1'}, {'value': '3190', 'units': 'cm-1'}, {'value': '2973', 'units': 'cm-1'}, {'value': '2873', 'units': 'cm-1'}, {'value': '1669', 'units': 'cm-1'}, {'value': '1646', 'units': 'cm-1'}, {'value': '1602', 'units': 'cm-1'}, {'value': '1495', 'units': 'cm-1'}, {'value': '1178', 'units': 'cm-1'}, {'value': '828', 'units': 'cm-1'}]}]}
# Input text:
#  Nicotine: FT-IR (KBr, cm-1): ν = 3025, 2970, 2870, 1691, 1677, 904, 717.
# Parsed IR Data:
#   {'ir_spectra': [{'solvent': 'KBr', 'peaks': [{'value': '3025', 'units': 'cm-1'}, {'value': '2970', 'units': 'cm-1'}, {'value': '2870', 'units': 'cm-1'}, {'value': '1691', 'units': 'cm-1'}, {'value': '1677', 'units': 'cm-1'}, {'value': '904', 'units': 'cm-1'}, {'value': '717', 'units': 'cm-1'}]}]}
# Input text:
#  [MBNT]Cl: FT-IR (KBr, cm-1): ν =3412, 3043, 2958, 1632, 1610, 1451, 1197, 916, 703, 472
# Parsed IR Data:
#   {'ir_spectra': [{'solvent': 'KBr', 'peaks': [{'value': '3412', 'units': 'cm-1'}, {'value': '3043', 'units': 'cm-1'}, {'value': '2958', 'units': 'cm-1'}, {'value': '1632', 'units': 'cm-1'}, {'value': '1610', 'units': 'cm-1'}, {'value': '1451', 'units': 'cm-1'}, {'value': '1197', 'units': 'cm-1'}, {'value': '916', 'units': 'cm-1'}, {'value': '703', 'units': 'cm-1'}, {'value': '472', 'units': 'cm-1'}]}]}

# %% [markdown]
# The next part is to try to read similar data strings from documents and parse them. For this we need an example which has the same tipe of sentences as the ones in the examples above. Most articles do not present information in these formats, however an example with supplementary information could be parsed to obtain the same data.

# %%
# The line of code (LOC) below imports the document object from the CDE library 
from chemdataextractor import Document

# define the input file (put it in the same directory as the source files or add 
# the complete path to the file, e.g.
# 'c:/users/user1/documents/file.pdf')

# The file used in this example was obtained from:
# http://www.rsc.org/suppdata/c5/ra/c5ra19028b/c5ra19028b1.pdf
# This is the supplementary material for the article 
# https://pubs.rsc.org/en/content/articlelanding/2015/ra/c5ra19028b
# Hajipour, A. R., Boostani, E., & Mohammadsaleh, F. (2015). 
# Copper (I) catalyzed Sonogashira reactions promoted by monobenzyl nicotinium chloride, 
# a N-donor quaternary ammonium salt. RSC Advances, 5(114), 94369-94374.
filepath = "IRSpectroscopy/c5ra19028b1.pdf"

# open de file in read binary mode
f = open(filepath, 'rb')

# create a document object from the file
doc = Document.from_file(f)

# %% [markdown]
# CDE provides the serialize  operation for summarising all entities, joining together abreviations, and capitalised or uncapitalised occurrences.
# As the following example shows it also extracts data when it is found in the appropriate format for parsing.

# %%
serialised=doc.records.serialize()
print(len(serialised))
serialised
# Out:
# 18
# [{'names': ['Copper(I)']},
#  {'names': ['monobenzyl nicotinium chloride a N- donor quaternary ammonium']},
#  {'names': ['Nicotine']},
#  {'ir_spectra': [{'solvent': 'KBr',
#     'peaks': [{'value': '3025', 'units': 'cm-1'},
#      {'value': '2970', 'units': 'cm-1'},
#      {'value': '2870', 'units': 'cm-1'},
#      {'value': '1691', 'units': 'cm-1'},
#      {'value': '1677', 'units': 'cm-1'},
#      {'value': '904', 'units': 'cm-1'},
#      {'value': '717', 'units': 'cm-1'}]}]},
#  {'ir_spectra': [{'solvent': 'KBr',
#     'peaks': [{'value': '3412', 'units': 'cm-1'},
#      {'value': '3043', 'units': 'cm-1'},
#      {'value': '2958', 'units': 'cm-1'},
#      {'value': '1632', 'units': 'cm-1'},
#      {'value': '1610', 'units': 'cm-1'},
#      {'value': '1451', 'units': 'cm-1'},
#      {'value': '1197', 'units': 'cm-1'},
#      {'value': '916', 'units': 'cm-1'},
#      {'value': '703', 'units': 'cm-1'},
#      {'value': '472', 'units': 'cm-1'}]}]},
#  {'names': ['[DBNT][Cu4Cl5]']},
#  {'ir_spectra': [{'solvent': 'KBr',
#     'peaks': [{'value': '3401', 'units': 'cm-1'},
#      {'value': '3040', 'units': 'cm-1'},
#      {'value': '2945', 'units': 'cm-1'},
#      {'value': '1635', 'units': 'cm-1'},
#      {'value': '1611', 'units': 'cm-1'},
#      {'value': '1455', 'units': 'cm-1'},
#      {'value': '1213', 'units': 'cm-1'},
#      {'value': '918', 'units': 'cm-1'},
#      {'value': '704', 'units': 'cm-1'},
#      {'value': '475', 'units': 'cm-1'}]}]},
#  {'names': ['monobenzyl nicotinium chloride']},
#  {'names': ['monobenzyl nicotinium chlorid']},
#  {'names': ['dibenzyl nicotinium chloride']},
#  {'names': ['dibenzyl nicotinium chlorid']},
#  {'names': ['OMe']},
#  {'names': ['13C']},
#  {'names': ['Cl']},
#  {'names': ['DMSO']},
#  {'names': ['N']},
#  {'names': ['1H-NMR']},
#  {'names': ['CDCl3']}]

# %%
serialised
# Out:
# [{'names': ['Copper(I)']},
#  {'names': ['monobenzyl nicotinium chloride a N- donor quaternary ammonium']},
#  {'names': ['Nicotine']},
#  {'ir_spectra': [{'solvent': 'KBr',
#     'peaks': [{'value': '3025', 'units': 'cm-1'},
#      {'value': '2970', 'units': 'cm-1'},
#      {'value': '2870', 'units': 'cm-1'},
#      {'value': '1691', 'units': 'cm-1'},
#      {'value': '1677', 'units': 'cm-1'},
#      {'value': '904', 'units': 'cm-1'},
#      {'value': '717', 'units': 'cm-1'}]}]},
#  {'ir_spectra': [{'solvent': 'KBr',
#     'peaks': [{'value': '3412', 'units': 'cm-1'},
#      {'value': '3043', 'units': 'cm-1'},
#      {'value': '2958', 'units': 'cm-1'},
#      {'value': '1632', 'units': 'cm-1'},
#      {'value': '1610', 'units': 'cm-1'},
#      {'value': '1451', 'units': 'cm-1'},
#      {'value': '1197', 'units': 'cm-1'},
#      {'value': '916', 'units': 'cm-1'},
#      {'value': '703', 'units': 'cm-1'},
#      {'value': '472', 'units': 'cm-1'}]}]},
#  {'names': ['[DBNT][Cu4Cl5]']},
#  {'ir_spectra': [{'solvent': 'KBr',
#     'peaks': [{'value': '3401', 'units': 'cm-1'},
#      {'value': '3040', 'units': 'cm-1'},
#      {'value': '2945', 'units': 'cm-1'},
#      {'value': '1635', 'units': 'cm-1'},
#      {'value': '1611', 'units': 'cm-1'},
#      {'value': '1455', 'units': 'cm-1'},
#      {'value': '1213', 'units': 'cm-1'},
#      {'value': '918', 'units': 'cm-1'},
#      {'value': '704', 'units': 'cm-1'},
#      {'value': '475', 'units': 'cm-1'}]}]},
#  {'names': ['monobenzyl nicotinium chloride']},
#  {'names': ['monobenzyl nicotinium chlorid']},
#  {'names': ['dibenzyl nicotinium chloride']},
#  {'names': ['dibenzyl nicotinium chlorid']},
#  {'names': ['OMe']},
#  {'names': ['13C']},
#  {'names': ['Cl']},
#  {'names': ['DMSO']},
#  {'names': ['N']},
#  {'names': ['1H-NMR']},
#  {'names': ['CDCl3']}]

# %% [markdown]
# The same processing on the full article yields additional data such as NMR spectra

# %%
filepath = "IRSpectroscopy/CooperICatalyzedSogashira.html"

# open de file in read binary mode
f = open(filepath, 'rb')

# create a document object from the file
doc = Document.from_file(f)

serialised=doc.records.serialize()
print(len(serialised))
serialised
# Out:
# 131
# [{'names': ['N-donor quaternary ammonium']},
#  {'names': ['alkynes']},
#  {'names': ['acetylene']},
#  {'names': ['aryl alkynes']},
#  {'names': ['aryl']},
#  {'names': ['C–N']},
#  {'names': ['C–O']},
#  {'names': ['triphenylphosphine']},
#  {'names': ['1,10-phenanthroline']},
#  {'names': ['ethylenediamine']},
#  {'names': ['N,N-dimethylglycine']},
#  {'names': ['choline chloride']},
#  {'names': ['C–C and C–S']},
#  {'names': ['carbon dioxide']},
#  {'names': ['cyclic carbonates']},
#  {'names': ['monobenzylnicotinium bromide']},
#  {'names': ['dibenzylnicotinium bromide']},
#  {'names': ['1-benzyl-4-aza-1-azoniabicyclo[2.2.2]octane chloride']},
#  {'names': ['DABCO chloride']},
#  {'names': ['1-benzyl-1-methyl-2-(pyridin-3-yl)pyrrolidin-1-ium chloride']},
#  {'names': ['1-benzyl-3-(1-benzyl-1-methylpyrrolidin-1-ium-2-yl)-pyridin-1-ium dichloride']},
#  {'names': ['Monobenzylnicotininium chloride [MBNT]Cl']},
#  {'names': ['dibenzyl nicotinium dichloride']},
#  {'names': ['quaternary ammonium cation N,N′-diallylmorpholinium']},
#  {'names': ['NMP']},
#  {'names': ['nitrogen-coordinating']},
#  {'names': ['N2 atmosphere.b']},
#  {'names': ['3-NO2']},
#  {'names': ['2-NO2']},
#  {'names': ['4-CHO']},
#  {'names': ['4-MeCO']},
#  {'names': ['4-I']},
#  {'names': ['4-Br']},
#  {'names': ['4-Cl']},
#  {'names': ['3-Cl']},
#  {'names': ['2-Cl']},
#  {'names': ['9-Bromophenanthrene']},
#  {'names': ['1-Bromonaphthalene']},
#  {'names': ['2-Bromopyridine']},
#  {'names': ['halogen']},
#  {'names': ['cyano']},
#  {'names': ['nitro']},
#  {'names': ['methoxy']},
#  {'names': ['carbonyl']},
#  {'names': ['2-bromonitrobenzene']},
#  {'names': ['2-bromochlorobenene']},
#  {'names': ['4-bromoanisole']},
#  {'names': ['4-iodoanisole']},
#  {'names': ['aryl chlorides']},
#  {'names': ['bromides']},
#  {'names': ['3-nitroiodobenzene']},
#  {'names': ['N']},
#  {'names': ['monobenzyl nicotinium']},
#  {'names': ['K3PO4']},
#  {'names': ['acetylide']},
#  {'names': ['copper phenylacetylide']},
#  {'names': ['phenylacetylide']},
#  {'names': ['Pd']},
#  {'names': ['pre-catalysts'], 'roles': ['product']},
#  {'names': ['Monobenzylnicotinium chloride [MBNT]Cl']},
#  {'names': ['n-hexane']},
#  {'names': ['Dibenzylnicotinium chloride [DBNT]Cl2']},
#  {'names': ['HCl']},
#  {'names': ['H2O']},
#  {'names': ['CaCl2']},
#  {'names': ['silica gel']},
#  {'names': ['hexane']},
#  {'names': ['arylalkyne']},
#  {'names': ['[ monobenzyl nicotinium]+[Cu4Cl5]−']},
#  {'names': ['aromatic alkynes']},
#  {'names': ['copper(I) chloride']},
#  {'names': ['Monobenzyl nicotinium chloride',
#    'monobenzyl nicotinium chloride',
#    'monobenzylnicotinium chloride']},
#  {'names': ['dibenzylnicotinium chloride', 'dibenzyl nicotinium chloride']},
#  {'names': ['carbon']},
#  {'names': ['phosphonium']},
#  {'names': ['1,4-diazabicyclo[2.2.2]-octane', 'DABCO']},
#  {'names': ['N-benzyl']},
#  {'names': ['ammonium']},
#  {'names': ['[Cu4Cl5]−']},
#  {'names': ['K3PO4·3H2O'], 'labels': ['2']},
#  {'names': ['K3PO4·3H2O'], 'labels': ['1']},
#  {'names': ['iodobenzene']},
#  {'names': ['alkyne']},
#  {'names': ['Cl']},
#  {'names': ['4-MeO']},
#  {'names': ['4-NO2']},
#  {'names': ['4-CN']},
#  {'names': ['aryl bromides', 'Aryl bromides']},
#  {'names': ['Cu(III)']},
#  {'names': ['copper(III)']},
#  {'names': ['benzyl chloride']},
#  {'names': ['acetonitrile']},
#  {'names': ['dichloromethane']},
#  {'names': ['DMSO-d6']},
#  {'names': ['C17H21Cl5Cu4N2']},
#  {'names': ['Cu']},
#  {'names': ['C24H28Cl6Cu4N2']},
#  {'names': ['EtOAc']},
#  {'names': ['1-Nitro-4-(phenylethynyl)benzene'],
#   'nmr_spectra': [{'nucleus': '13C',
#     'solvent': 'CDCl3',
#     'frequency': '100',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '147.0'},
#      {'shift': '132.3'},
#      {'shift': '131.9'},
#      {'shift': '130.3'},
#      {'shift': '129.3'},
#      {'shift': '128.5'},
#      {'shift': '123.7'},
#      {'shift': '122.1'},
#      {'shift': '94.7'},
#      {'shift': '87.50'}]},
#    {'nucleus': '1H',
#     'solvent': 'CDCl3',
#     'frequency': '400',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '8.22',
#       'multiplicity': 'd',
#       'coupling': '8.8',
#       'coupling_units': 'Hz',
#       'number': '2H'},
#      {'shift': '7.66',
#       'multiplicity': 'd',
#       'coupling': '8.8',
#       'coupling_units': 'Hz',
#       'number': '2H'},
#      {'shift': '7.52', 'multiplicity': 'm', 'number': '2H'},
#      {'shift': '7.39', 'multiplicity': 'm', 'number': '3H'}]}]},
#  {'names': ['1-Methoxy-4-(phenylethynyl)benzene'],
#   'nmr_spectra': [{'nucleus': '13C',
#     'solvent': 'CDCl3',
#     'frequency': '100',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '159.60'},
#      {'shift': '133.0'},
#      {'shift': '131.4'},
#      {'shift': '128.30'},
#      {'shift': '127.90'},
#      {'shift': '123.60'},
#      {'shift': '115.40'},
#      {'shift': '114.0'},
#      {'shift': '89.30'},
#      {'shift': '88.0'},
#      {'shift': '55.30'}]},
#    {'nucleus': '1H',
#     'solvent': 'CDCl3',
#     'frequency': '400',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '7.42', 'multiplicity': 'm', 'number': '2H'},
#      {'shift': '7.38',
#       'multiplicity': 'd',
#       'coupling': '8.8',
#       'coupling_units': 'Hz',
#       'number': '2H'},
#      {'shift': '7.25', 'multiplicity': 'm', 'number': '3H'},
#      {'shift': '6.79',
#       'multiplicity': 'd',
#       'coupling': '8.8',
#       'coupling_units': 'Hz',
#       'number': '2H'},
#      {'shift': '3.73', 'multiplicity': 's', 'number': '3H'}]}]},
#  {'names': ['2-(Phenylethynyl)pyridine'],
#   'nmr_spectra': [{'nucleus': '1H',
#     'solvent': 'CDCl3',
#     'frequency': '400',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '8.55',
#       'multiplicity': 'd',
#       'coupling': '5',
#       'coupling_units': 'Hz',
#       'number': '1H'},
#      {'shift': '7.58–7.63', 'multiplicity': 'm', 'number': '1H'},
#      {'shift': '7.51–7.55', 'multiplicity': 'm', 'number': '2H'},
#      {'shift': '7.46',
#       'multiplicity': 'd',
#       'coupling': '7',
#       'coupling_units': 'Hz',
#       'number': '1H'},
#      {'shift': '7.26–7.35', 'multiplicity': 'm', 'number': '2H'},
#      {'shift': '7.20', 'multiplicity': 's', 'number': '1H'},
#      {'shift': '7.12–7.17', 'multiplicity': 'm', 'number': '1H'}]}]},
#  {'names': ['1,2-Diphenylethyne'],
#   'nmr_spectra': [{'nucleus': '13C',
#     'solvent': 'CDCl3',
#     'frequency': '100',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '131.70'},
#      {'shift': '128.50'},
#      {'shift': '128.40'},
#      {'shift': '123.4'},
#      {'shift': '89.60'}]},
#    {'nucleus': '1H',
#     'solvent': 'CDCl3',
#     'frequency': '400',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '7.57–7.60', 'multiplicity': 'm', 'number': '4H'},
#      {'shift': '7.37–7.41', 'multiplicity': 'm', 'number': '6H'}]}]},
#  {'names': ['Copper(I)', 'copper(I)']},
#  {'names': ['quaternary ammonium']},
#  {'names': ['C–C']},
#  {'names': ['methanol']},
#  {'names': ['[DBNT][Cu4Cl6]']},
#  {'names': ['DMSO']},
#  {'names': ['CuCl']},
#  {'names': ['N2']},
#  {'names': ['aryl halide', 'Aryl halide']},
#  {'names': ['H']},
#  {'names': ['aryl iodides']},
#  {'names': ['[MBNT]Cl'],
#   'nmr_spectra': [{'nucleus': '13C',
#     'solvent': 'CDCl3',
#     'frequency': '100',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '143.83'},
#      {'shift': '143.67'},
#      {'shift': '143.39'},
#      {'shift': '132.47'},
#      {'shift': '129.52'},
#      {'shift': '129.28'},
#      {'shift': '129.22'},
#      {'shift': '66.53'},
#      {'shift': '63.74'},
#      {'shift': '56.22'},
#      {'shift': '40.12'},
#      {'shift': '35.61'},
#      {'shift': '26.23'}]}]},
#  {'names': ['nicotine']},
#  {'names': ['2H']},
#  {'names': ['1-Nitro-3-phenylethynyl-benzene'],
#   'nmr_spectra': [{'nucleus': '1H',
#     'solvent': 'CDCl3',
#     'frequency': '400',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '8.31', 'multiplicity': 'dd', 'number': '1H'},
#      {'shift': '8.11', 'multiplicity': 'm', 'number': '1H'},
#      {'shift': '7.76', 'multiplicity': 'ddd', 'number': '1H'},
#      {'shift': '7.76', 'multiplicity': 'ddd', 'number': '1H'},
#      {'shift': '7.46–7.50', 'multiplicity': 'm', 'number': '3H'},
#      {'shift': '7.31–7.32', 'multiplicity': 'm', 'number': '3H'}]},
#    {'nucleus': '13C',
#     'solvent': 'CDCl3',
#     'frequency': '100',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '148.2'},
#      {'shift': '137.2'},
#      {'shift': '131.8'},
#      {'shift': '129.4'},
#      {'shift': '129.1'},
#      {'shift': '128.5'},
#      {'shift': '126.4'},
#      {'shift': '125.2'},
#      {'shift': '122.9'},
#      {'shift': '122.2'},
#      {'shift': '91.9'},
#      {'shift': '86.9'}]}],
#   'ir_spectra': [{'solvent': 'KBr',
#     'peaks': [{'value': '2930', 'units': 'cm−1'},
#      {'value': '2214', 'units': 'cm−1'},
#      {'value': '1596', 'units': 'cm−1'},
#      {'value': '1513', 'units': 'cm−1'},
#      {'value': '1345', 'units': 'cm−1'},
#      {'value': '853', 'units': 'cm−1'}]}]},
#  {'names': ['1-(4-Phenylethynyl-phenyl)-ethanone'],
#   'nmr_spectra': [{'nucleus': '1H',
#     'solvent': 'DMSO',
#     'frequency': '300',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '8.0', 'multiplicity': 'd', 'number': '2H'},
#      {'shift': '7.7', 'multiplicity': 'd', 'number': '2H'},
#      {'shift': '7.6', 'multiplicity': 'm', 'number': '2H'},
#      {'shift': '7.5', 'multiplicity': 'm', 'number': '3H'},
#      {'shift': '2.6', 'multiplicity': 's', 'number': '3H'}]},
#    {'nucleus': '13C',
#     'solvent': 'CDCl3',
#     'frequency': '100',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '197.5'},
#      {'shift': '136.3'},
#      {'shift': '131.7'},
#      {'shift': '131.6'},
#      {'shift': '128.8'},
#      {'shift': '128.5'},
#      {'shift': '128.2'},
#      {'shift': '122.6'},
#      {'shift': '92.7'},
#      {'shift': '88.6'},
#      {'shift': '26.6'}]}],
#   'ir_spectra': [{'solvent': 'KBr',
#     'peaks': [{'value': '3080', 'units': 'cm−1'},
#      {'value': '2930', 'units': 'cm−1'},
#      {'value': '2216', 'units': 'cm−1'},
#      {'value': '1679', 'units': 'cm−1'},
#      {'value': '1603', 'units': 'cm−1'},
#      {'value': '1441', 'units': 'cm−1'},
#      {'value': '1403', 'units': 'cm−1'},
#      {'value': '1265', 'units': 'cm−1'},
#      {'value': '1175', 'units': 'cm−1'}]}]},
#  {'names': ['aryl halides']},
#  {'names': ['palladium']},
#  {'names': ['[DBNT]Cl2'],
#   'nmr_spectra': [{'nucleus': '13C',
#     'solvent': 'DMSO-d6',
#     'frequency': '100',
#     'frequency_units': 'MHz',
#     'peaks': [{'shift': '148.20'},
#      {'shift': '147.56'},
#      {'shift': '146.15'},
#      {'shift': '132.91'},
#      {'shift': '132.47'},
#      {'shift': '130.30'},
#      {'shift': '129.48'},
#      {'shift': '129.22'},
#      {'shift': '128.96'},
#      {'shift': '128.37'},
#      {'shift': '74.57'},
#      {'shift': '65.16'},
#      {'shift': '63.77'},
#      {'shift': '62.94'},
#      {'shift': '41.23'},
#      {'shift': '25.58'},
#      {'shift': '18.69'}]}]},
#  {'names': ['Cu(I)']},
#  {'names': ['[MBNT][Cu4Cl5]']},
#  {'names': ['KOH', 'K2CO3', 'K3PO4·3H2O'], 'labels': ['3']},
#  {'names': ['Br']},
#  {'names': ['copper']},
#  {'names': ['phenylacetylene']},
#  {'names': ['13C']},
#  {'names': ['DMF']},
#  {'names': ['1H']},
#  {'names': ['CDCl3']}]
